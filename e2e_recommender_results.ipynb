# %% [markdown]
# # Crawling over the e2e recommender results
# Use this notebook to synthesize experiment results for the paper.

# %%
import os
import json
import pandas as pd

# %%
e2e_output_dir = 'e2e_output'
rows = {}
for d in os.listdir(e2e_output_dir):
    row = {}
    if os.path.isdir(os.path.join(e2e_output_dir, d)):
        with open(os.path.join(e2e_output_dir, d, 'log.json')) as f:
            data = json.load(f)
            for item in data:
                if 'mAP' in item:
                    row['mAP'] = item['mAP']
                if 'train_accuracies' in item:
                    row['train_accuracy'] = item['train_accuracies'][-1]
                if 'test_accuracies' in item:
                    row['test_accuracy'] = item['test_accuracies'][-1]
                if 'e2e_config' in item:
                    row['learning_rate'] = item['e2e_config']['train']['learning_rate']
                    row['dropout_prob'] = item['e2e_config']['train']['dropout_prob']
                    row['n_clusters'] = item['e2e_config']['data_provider']['cluster_config']['n_clusters']
            rows[d] = row

experiments = pd.DataFrame.from_dict(rows, orient='index')
experiments
# Out:
#                                             learning_rate  dropout_prob  \
# execution_4104480fda99f1c70abe79a51d85bf95         0.0002           0.3
# execution_57e1e364ed8e198808e178f62b6a5050         0.0003           0.3
# execution_10e9bb4a5ee2e7e5a6b871db60c33277         0.0003           0.3
# execution_937d108ce27c7d8f3088857bde0915d7         0.0001           0.3
# execution_a60b2ad39f3995841f5997d4b8e8da5a         0.0001           0.3
# execution_6a8b444d583c8ae3a1fbeee5f87e613a         0.0003           0.3
# execution_cb5010c653b7ce44f3803f837d8c05b1         0.0001           0.3
# execution_b0e179b0b23bf50997d13f795dd4f50a         0.0005           0.3
# execution_7ba5e05437d4ff03be80885d37f2cfba         0.0001           0.4
# execution_a7aea9999821565346f8f434bc4f7f14         0.0001           0.3
# execution_15e9924b6c59781e70fdc9a7e0a9f25e         0.0001           0.3
# execution_4763f4069ef54b226435a6e166656b0e         0.0001           0.3
# execution_328ae92aa231d5bb5263fd710a1373ad         0.0001           0.2
# execution_0de93cd01eac6145597e0ac991ed545c         0.0001           0.2
# execution_cd10ab2048081a574d189285dbfd073e         0.0003           0.3
# execution_6ee3b63a3284677367917ea5312843b8         0.0001           0.2
# execution_77bed10b02c3cb2150554a84409e46b0         0.0003           0.3
#
#                                             n_clusters  train_accuracy  \
# execution_4104480fda99f1c70abe79a51d85bf95           5        0.599809
